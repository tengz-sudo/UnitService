# %%
from exp import *

# %load_ext autoreload
# %autoreload
# Out:
# utils are imported! yeah!

# %% [markdown]
# ## Run the fiscal year 2019 (2018.9.1-2019.8.31) 10am census

# %%
# change the census file dir to read different data, 
# must be a .csv with columns matched to the original census!!!
census_file = "../Data/2020-01-10Census and Surgical Admits and Scheduled 2.csv"
fyear = 2019
exp = Experiment(census_file, fyear)
# Out:
# /Users/Teng/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Read Census Data Size: (560583, 27)
# /Users/Teng/Desktop/UnitService/Codes/utils.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.df_census_year['Service.x'] = self.df_census_year.apply(fill_x_use_y, axis = 1)
# 100%|██████████| 103047/103047 [00:13<00:00, 7793.57it/s]
# /Users/Teng/Desktop/UnitService/Codes/utils.py:183: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# run the integer programming. 
# the resulting allocation is printed in the bottom
exp.run_model()
# Out:
# Academic license - for non-commercial use only
# Optimize a model with 21 rows, 84 columns and 104 nonzeros
# Model has 546 quadratic objective terms
# Variable types: 0 continuous, 84 integer (84 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e+03, 9e+05]
#   QObjective range [1e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 243756.25000
# Presolve removed 16 rows and 55 columns
# Presolve time: 0.00s
# Presolved: 61 rows, 85 columns, 197 nonzeros
# Variable types: 0 continuous, 85 integer (85 binary)
# Found heuristic solution: objective 167756.85000
#
# Root relaxation: objective 1.628887e+05, 34 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 162888.650    0   10 167756.850 162888.650  2.90%     -    0s
# ...

# %%
exp.service_count_daily.describe().transpose()
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# HemeOnc and StemCell  365.0  27.320548  3.657559  14.0  25.0  27.0  29.0  39.0
# Cardiology            365.0  15.263014  3.342513   4.0  13.0  15.0  18.0  23.0
# Green Team            365.0   8.550685  2.877686   2.0   7.0   8.0  10.0  17.0
# Pulmonary             365.0   7.150685  2.560645   2.0   6.0   7.0   8.0  16.0
# General Surgery       365.0   6.071233  2.800190   0.0   4.0   6.0   8.0  16.0
# Red Team              365.0   5.136986  2.229393   0.0   3.0   5.0   7.0  11.0
# Neurosurgery          365.0   3.594521  2.131649   0.0   2.0   3.0   5.0  10.0
# Orthopedics           365.0   2.912329  1.783005   0.0   2.0   3.0   4.0   9.0
# Otolaryngology (ENT)  365.0   1.756164  1.494770   0.0   1.0   1.0   2.0   8.0
# Neurology             365.0   1.739726  1.464107   0.0   1.0   2.0   3.0   7.0
# Urology               365.0   0.810959  0.919801   0.0   0.0   1.0   1.0   4.0
# ...

# %%
# plot the result
# and print the number of over capacity days
exp.plot_results()
# Out:
# /Users/Teng/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# ----off-service-stats----
# [over_90%_cap_days, over_full_cap_days]
# PCU200 [1, 0]
# PCU300 [15, 3]
# PCU360 [0, 0]
# PCU400 [11, 0]
# PCU500 [15, 1]
# ----in-total----
# 42 4

# %% [markdown]
# ## Run the fiscal year 2019 (2018.9.1-2019.8.31) Midnight census

# %%
census_file = "../Data/Different_Census/2018_mid_census.csv"
fyear = 2019

exp = Experiment(census_file, fyear)
exp.run_model()
exp.plot_results()
# Out:
# /Users/Teng/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3296: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Read Census Data Size: (103047, 28)
# 100%|██████████| 103047/103047 [00:12<00:00, 8463.02it/s]
# In total 12 services
# Units: ['PCU200', 'PCU300', 'PCU360', 'PCU380', 'PCU400', 'PCU500', 'PCU520']
# Services: ['HemeOnc and StemCell', 'Cardiology', 'Green Team', 'Pulmonary', 'General Surgery', 'Red Team', 'Neurosurgery', 'Orthopedics', 'Otolaryngology (ENT)', 'Neurology', 'Urology', 'Plastic Surgery']
# Optimize a model with 21 rows, 84 columns and 104 nonzeros
# Model has 546 quadratic objective terms
# Variable types: 0 continuous, 84 integer (84 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e+03, 9e+05]
#   QObjective range [1e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
# ...

# %% [markdown]
# ## 2019 6 AM

# %%
census_file = "../Data/Different_Census/2018_6am_census.csv"
fyear = 2019

exp = Experiment(census_file, fyear)
exp.run_model()
exp.plot_results()
# Out:
# Read Census Data Size: (106760, 27)
# 100%|██████████| 106760/106760 [00:15<00:00, 7041.48it/s]
# In total 12 services
# Units: ['PCU200', 'PCU300', 'PCU360', 'PCU380', 'PCU400', 'PCU500', 'PCU520']
# Services: ['HemeOnc and StemCell', 'Cardiology', 'Green Team', 'Pulmonary', 'General Surgery', 'Red Team', 'Neurosurgery', 'Orthopedics', 'Otolaryngology (ENT)', 'Neurology', 'Urology', 'Plastic Surgery']
# Academic license - for non-commercial use only
# Optimize a model with 21 rows, 84 columns and 104 nonzeros
# Model has 546 quadratic objective terms
# Variable types: 0 continuous, 84 integer (84 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [8e+03, 9e+05]
#   QObjective range [1e+03, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 239379.85000
# Presolve removed 16 rows and 55 columns
# Presolve time: 0.01s
# Presolved: 61 rows, 85 columns, 197 nonzeros
# ...
