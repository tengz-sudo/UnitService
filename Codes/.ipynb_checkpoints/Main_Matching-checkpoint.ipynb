# %%
import pandas as pd
import numpy as np
import datetime
from utils import *
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# import numpy as np

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Read Data

# %%
census_file = "../Data/2019-09-13Census and Surgical Admits and Scheduled 2.csv"

df_census = pd.read_csv(census_file, index_col = 0)
df_census = convert_datatimes(df_census)
# Out:
# /Users/Teng/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# convert the service and dept names
df_census_converted = convert_service_name(df_census)
df_census_converted = convert_dept_name(df_census_converted)

# %%
# filter out the data by time
start_date = datetime.datetime(year = 2018, month = 9, day = 1)
end_date = datetime.datetime(year = 2019, month = 9, day = 1)
df_census_2019 = df_census_converted.loc[(df_census_converted['Effective Date/Time'] >= start_date) &
                                        (df_census_converted['Effective Date/Time'] < end_date)]

# %%
# add some columns
df_census_2019.loc[:,'Date']  = df_census_2019['Effective Date/Time'].dt.date

# %% [markdown]
# ## Unit-service explore

# %%
# print the major services in each unit
print_services_in_units(df_census_2019)
# Out:
# Major Services in [ NICU270 ] :::::::
# General Pediatrics    9449
# Cardiology              63
# Unknown                 28
# General Surgery         13
# Neurosurgery            10
# ENT                      6
# Green Team               1
# Orthopedics              1
# Pulmonary                1
# Urology                  1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ NN ] :::::::
# General Pediatrics    9295
# Unknown                  5
# General Surgery          1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU160 ] :::::::
# HemeOnc/SCT                 5316
# HemeOnc and StemCell        3403
# Unknown                       47
# General Pediatrics            33
# General Surgery               17
# Interventional Radiology       5
# Neurology                      5
# Orthopedics                    5
# Green Team                     4
# ENT                            4
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU300 ] :::::::
# Green Team            2019
# Red Team              1534
# General Pediatrics    1297
# General Surgery       1033
# Liver Transplant       436
# ENT                    309
# Urology                279
# Unknown                237
# Pulmonary              232
# Transplant             203
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU200 ] :::::::
# Cardiology            5538
# General Pediatrics     953
# General Surgery        371
# HemeOnc/SCT            216
# Pulmonary              182
# ENT                    136
# Red Team               126
# Green Team              74
# Unknown                 44
# Orthopedics             29
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU400 ] :::::::
# General Pediatrics    2348
# Pulmonary             2107
# Neurosurgery          1271
# Orthopedics            808
# Neurology              616
# General Surgery        190
# Green Team             110
# Unknown                 56
# Red Team                49
# Pain                    46
# Name: Service.x, dtype: int64
#
#
# Major Services in [ CVICU220 ] :::::::
# Cardiology            7225
# General Pediatrics     134
# Unknown                 18
# ENT                      6
# Orthopedics              2
# General Surgery          2
# Red Team                 1
# Pulmonary                1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ MAT292 ] :::::::
# Unknown                    6192
# Gynecology & Obstetrics      48
# Gynecology                   41
# Maternal-Fetal Medicine       7
# General Surgery               7
# Neurosurgery                  4
# General Pediatrics            2
# Name: Service.x, dtype: int64
#
#
# Major Services in [ MAT192 ] :::::::
# Unknown                    5585
# Gynecology                   45
# Maternal-Fetal Medicine       5
# General Pediatrics            3
# Gynecology & Obstetrics       2
# Plastic Surgery               1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ ICN1 ] :::::::
# General Pediatrics    4991
# General Surgery          3
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PICU420 ] :::::::
# Unknown                 3681
# Neurosurgery             347
# General Pediatrics       327
# Pulmonary                 93
# General Surgery           76
# ENT                       72
# Anesthesia                66
# HemeOnc/SCT               52
# Orthopedics               44
# HemeOnc and StemCell      19
# Name: Service.x, dtype: int64
#
#
# Major Services in [ LDR ] :::::::
# Unknown                    3719
# Gynecology                   37
# Gynecology & Obstetrics       6
# Maternal-Fetal Medicine       5
# Neurosurgery                  3
# General Pediatrics            1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PICU320 ] :::::::
# Unknown               2554
# ENT                    170
# Pulmonary              159
# General Pediatrics     146
# Anesthesia              66
# Liver Transplant        48
# Orthopedics             47
# Transplant              45
# HemeOnc/SCT             39
# General Surgery         28
# Name: Service.x, dtype: int64
#
#
# Major Services in [ CCP ] :::::::
# General Pediatrics        3097
# Green Team                   3
# Unknown                      1
# Development & Behavior       1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU360 ] :::::::
# HemeOnc/SCT           929
# General Pediatrics    689
# General Surgery       481
# Green Team            131
# ENT                   104
# Orthopedics            70
# Plastic Surgery        60
# Red Team               55
# Pulmonary              43
# Unknown                43
# Name: Service.x, dtype: int64
#
#
# Major Services in [ ICN2 ] :::::::
# General Pediatrics    2143
# Unknown                  5
# Cardiology               3
# Name: Service.x, dtype: int64
#
#
# Major Services in [ MAT350 ] :::::::
# Unknown       1303
# Gynecology      22
# Name: Service.x, dtype: int64
#
#
# Major Services in [ NICU260 ] :::::::
# General Pediatrics    1268
# Cardiology               1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ SEQN ] :::::::
# General Pediatrics    1226
# Unknown                  2
# Name: Service.x, dtype: int64
#
#
# Major Services in [ SSU ] :::::::
# ENT                     270
# Red Team                258
# Immunology & Allergy     77
# Neurology                70
# Cardiology               68
# Orthopedics              46
# Green Team               40
# General Pediatrics       36
# General Surgery          33
# Pulmonary                21
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PEC ] :::::::
# General Pediatrics    942
# General Surgery         4
# Unknown                 3
# Neurology               1
# Pulmonary               1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ CVICU320 ] :::::::
# Cardiology              724
# General Pediatrics       16
# Unknown                   6
# Red Team                  3
# HemeOnc/SCT               3
# General Surgery           2
# ENT                       1
# Orthopedics               1
# HemeOnc and StemCell      1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU380 ] :::::::
# General Pediatrics    104
# General Surgery        91
# Green Team             80
# Red Team               37
# ENT                    34
# Pulmonary              32
# Unknown                17
# Plastic Surgery        12
# Orthopedics            11
# HemeOnc/SCT             3
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PAC ] :::::::
# Cardiology                  50
# Interventional Radiology    48
# ENT                         40
# Orthopedics                 40
# General Surgery             28
# General Pediatrics          20
# Urology                     18
# Plastic Surgery             10
# Neurosurgery                 9
# Transplant                   9
# Name: Service.x, dtype: int64
#
#
# Major Services in [ APU ] :::::::
# Green Team            29
# ENT                    8
# Cardiology             8
# HemeOnc/SCT            4
# Dermatology            3
# Neurology              3
# General Surgery        2
# Anesthesia             2
# Pulmonary              2
# General Pediatrics     2
# Name: Service.x, dtype: int64
#
#
# Major Services in [ BCDHPAC ] :::::::
# HemeOnc/SCT    40
# Neurology       1
# Name: Service.x, dtype: int64
#
#
# Major Services in [ INFUS ] :::::::
# HemeOnc/SCT    26
# Name: Service.x, dtype: int64

# %% [markdown]
# Note: it seems that PCU380 is (re?)opened since mid Jun, 2019. Thus we might want to consider the data up to
# May 2019

# %%
# end_date = datetime.datetime(year = 2019, month = 5, day =31)
# df_census_2019_to_may = df_census_2019.loc[df_census_2019['Effective Date/Time']<=end_date]

# %% [markdown]
# ## Filter out specific units and services

# %%
# Units to consider
units_to_consider = ['PCU160', 'PCU200', 'PCU300', 'PCU360', 'PCU400']
df_to_work = df_census_2019.loc[df_census_2019['Dept Abbrev'].isin(units_to_consider)]

# %%
df_to_work['Service.x'].value_counts()
# Out:
# HemeOnc/SCT                  6485
# Cardiology                   5551
# General Pediatrics           5320
# HemeOnc and StemCell         3457
# Pulmonary                    2565
# Green Team                   2338
# General Surgery              2092
# Red Team                     1767
# Neurosurgery                 1288
# Orthopedics                  1038
# Neurology                     635
# ENT                           583
# Liver Transplant              436
# Unknown                       427
# Urology                       296
# Plastic Surgery               270
# Transplant                    205
# Pain                          192
# Interventional Radiology       79
# Anesthesia                     36
# Kidney Transplant              24
# Cardiovascular Transplant      18
# Gynecology                     17
# Immunology & Allergy            1
# Name: Service.x, dtype: int64

# %%
service_thresh = 10
temp = df_to_work['Service.x'].value_counts().reset_index()
services_to_consider = temp.loc[temp['Service.x'] >= service_thresh]['index'].to_list()
print('consider', len(services_to_consider), 'services!!')
df_to_work = df_to_work.loc[df_to_work['Service.x'].isin(services_to_consider)]
# Out:
# consider 23 services!!

# %%
services_to_consider
# Out:
# ['HemeOnc/SCT',
#  'Cardiology',
#  'General Pediatrics',
#  'HemeOnc and StemCell',
#  'Pulmonary',
#  'Green Team',
#  'General Surgery',
#  'Red Team',
#  'Neurosurgery',
#  'Orthopedics',
#  'Neurology',
#  'ENT',
#  'Liver Transplant',
#  'Unknown',
#  'Urology',
#  'Plastic Surgery',
#  'Transplant',
#  'Pain',
#  'Interventional Radiology',
#  'Anesthesia',
#  'Kidney Transplant',
#  'Cardiovascular Transplant',
#  'Gynecology']

# %%
print_services_in_units(df_to_work)
# Out:
# Major Services in [ PCU160 ] :::::::
# HemeOnc/SCT                 5316
# HemeOnc and StemCell        3403
# Unknown                       47
# General Pediatrics            33
# General Surgery               17
# Interventional Radiology       5
# Neurology                      5
# Orthopedics                    5
# Green Team                     4
# ENT                            4
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU300 ] :::::::
# Green Team            2019
# Red Team              1534
# General Pediatrics    1297
# General Surgery       1033
# Liver Transplant       436
# ENT                    309
# Urology                279
# Unknown                237
# Pulmonary              232
# Transplant             203
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU200 ] :::::::
# Cardiology            5538
# General Pediatrics     953
# General Surgery        371
# HemeOnc/SCT            216
# Pulmonary              182
# ENT                    136
# Red Team               126
# Green Team              74
# Unknown                 44
# Orthopedics             29
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU400 ] :::::::
# General Pediatrics    2348
# Pulmonary             2107
# Neurosurgery          1271
# Orthopedics            808
# Neurology              616
# General Surgery        190
# Green Team             110
# Unknown                 56
# Red Team                49
# Pain                    46
# Name: Service.x, dtype: int64
#
#
# Major Services in [ PCU360 ] :::::::
# HemeOnc/SCT           929
# General Pediatrics    689
# General Surgery       481
# Green Team            131
# ENT                   104
# Orthopedics            70
# Plastic Surgery        60
# Red Team               55
# Pulmonary              43
# Unknown                43
# Name: Service.x, dtype: int64

# %%
print_units_of_services(df_to_work)
# Out:
# Major Units of Service [ HemeOnc/SCT ] :::::::
# PCU160    5316
# PCU360     929
# PCU200     216
# PCU400      15
# PCU300       9
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Cardiology ] :::::::
# PCU200    5538
# PCU300      12
# PCU400       1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ General Pediatrics ] :::::::
# PCU400    2348
# PCU300    1297
# PCU200     953
# PCU360     689
# PCU160      33
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ HemeOnc and StemCell ] :::::::
# PCU160    3403
# PCU200      22
# PCU360      16
# PCU300      16
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Pulmonary ] :::::::
# PCU400    2107
# PCU300     232
# PCU200     182
# PCU360      43
# PCU160       1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Green Team ] :::::::
# PCU300    2019
# PCU360     131
# PCU400     110
# PCU200      74
# PCU160       4
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ General Surgery ] :::::::
# PCU300    1033
# PCU360     481
# PCU200     371
# PCU400     190
# PCU160      17
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Red Team ] :::::::
# PCU300    1534
# PCU200     126
# PCU360      55
# PCU400      49
# PCU160       3
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Neurosurgery ] :::::::
# PCU400    1271
# PCU200       9
# PCU300       7
# PCU360       1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Orthopedics ] :::::::
# PCU400    808
# PCU300    126
# PCU360     70
# PCU200     29
# PCU160      5
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Neurology ] :::::::
# PCU400    616
# PCU300      6
# PCU160      5
# PCU360      5
# PCU200      3
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ ENT ] :::::::
# PCU300    309
# PCU200    136
# PCU360    104
# PCU400     30
# PCU160      4
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Liver Transplant ] :::::::
# PCU300    436
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Unknown ] :::::::
# PCU300    237
# PCU400     56
# PCU160     47
# PCU200     44
# PCU360     43
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Urology ] :::::::
# PCU300    279
# PCU360      7
# PCU400      5
# PCU200      5
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Plastic Surgery ] :::::::
# PCU300    141
# PCU360     60
# PCU400     42
# PCU200     24
# PCU160      3
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Transplant ] :::::::
# PCU300    203
# PCU360      1
# PCU200      1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Pain ] :::::::
# PCU300    113
# PCU400     46
# PCU360     22
# PCU200     10
# PCU160      1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Interventional Radiology ] :::::::
# PCU300    64
# PCU360     7
# PCU160     5
# PCU200     2
# PCU400     1
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Anesthesia ] :::::::
# PCU400    13
# PCU300    12
# PCU200     7
# PCU360     4
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Kidney Transplant ] :::::::
# PCU300    24
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Cardiovascular Transplant ] :::::::
# PCU200    18
# Name: Dept Abbrev, dtype: int64
#
#
# Major Units of Service [ Gynecology ] :::::::
# PCU300    16
# PCU360     1
# Name: Dept Abbrev, dtype: int64

# %% [markdown]
# ## Rename 160 to 500:
# from now on, we are switching 160 to 500

# %%
def switch_160_to_500(d):
    if d == 'PCU160':
        return 'PCU500'
    else:
        return d
df_to_work['Dept Abbrev'] = df_to_work['Dept Abbrev'].apply(switch_160_to_500)

# %%
units_to_consider = ['PCU200', 'PCU300', 'PCU360', 'PCU400', 'PCU500']

# %% [markdown]
# ## Unit capacity

# %%
unit_daily_cap = df_to_work.groupby(['Dept Abbrev', 'Date']).size().reset_index()
unit_daily_cap = unit_daily_cap.rename(columns = {0:'Occupacy'})
unit_cap = unit_daily_cap.groupby('Dept Abbrev')['Occupacy'].max().reset_index()

# %%
unit_cap
# Out:
#   Dept Abbrev  Occupacy
# 0      PCU200        26
# 1      PCU300        26
# 2      PCU360        14
# 3      PCU400        25
# 4      PCU500        27

# %%
# fix from slides
unit_cap.loc[3, 'Occupacy'] = 24
unit_cap.loc[4, 'Occupacy'] = 49

# %%
unit_cap
# Out:
#   Dept Abbrev  Occupacy
# 0      PCU200        26
# 1      PCU300        26
# 2      PCU360        14
# 3      PCU400        24
# 4      PCU500        49

# %%
unit_cap_dict = {unit_cap.loc[i, 'Dept Abbrev']: unit_cap.loc[i, 'Occupacy'] for i in range(len(units_to_consider))}

# %%
unit_cap_dict
# Out:
# {'PCU200': 26, 'PCU300': 26, 'PCU360': 14, 'PCU400': 24, 'PCU500': 49}

# %% [markdown]
# ## Daily service counts

# %%
# service_count_daily = pd.DataFrame()
# df_service_range = df_census_2019.copy()
df_service_range = df_to_work.copy()


service = services_to_consider[0]
temp = df_service_range.loc[df_service_range['Service.x'] == service]
temp = temp.groupby('Date')['Service.x'].size().reset_index()
service_count_daily = temp.rename(columns = {'Service.x':service})

for service in services_to_consider[1:]:
    temp = df_service_range.loc[df_service_range['Service.x'] == service]
    temp = temp.groupby('Date')['Service.x'].size().reset_index()
    service_count_daily = service_count_daily.merge(temp.rename(columns = {'Service.x':service}), 
                                                    on = 'Date', how = 'left')
service_count_daily = service_count_daily.fillna(0)

# sanity check: if we missed some days
days_range = (service_count_daily['Date'].max() - service_count_daily['Date'].min()) / datetime.timedelta(days = 1)
assert (days_range+1 == service_count_daily.shape[0]), "Range not match!"

# %%
# daily stats for each service
temp = service_daily_stats(service_count_daily, services_to_consider)
temp.transpose().sort_values('50%', ascending = False)
# for service in temp.columns:
#     print(temp[service])
# Out:
#                            count       mean       std  min   25%   50%   75%  \
# HemeOnc/SCT                365.0  17.767123  3.647672  8.0  15.0  18.0  20.0
# Cardiology                 365.0  15.208219  3.312553  4.0  13.0  15.0  18.0
# General Pediatrics         365.0  14.575342  3.669438  4.0  12.0  14.0  17.0
# HemeOnc and StemCell       365.0   9.471233  2.042776  5.0   8.0   9.0  11.0
# Pulmonary                  365.0   7.027397  2.505886  2.0   5.0   7.0   8.0
# Green Team                 365.0   6.405479  2.514785  0.0   5.0   6.0   8.0
# General Surgery            365.0   5.731507  2.532041  0.0   4.0   6.0   7.0
# Red Team                   365.0   4.841096  2.193136  0.0   3.0   5.0   6.0
# Neurosurgery               365.0   3.528767  2.106340  0.0   2.0   3.0   5.0
# Orthopedics                365.0   2.843836  1.740041  0.0   2.0   3.0   4.0
# Neurology                  365.0   1.739726  1.464107  0.0   1.0   2.0   3.0
# Urology                    365.0   0.810959  0.919801  0.0   0.0   1.0   1.0
# Plastic Surgery            365.0   0.739726  0.935082  0.0   0.0   1.0   1.0
# ENT                        365.0   1.597260  1.370607  0.0   1.0   1.0   2.0
# Unknown                    365.0   1.169863  1.268239  0.0   0.0   1.0   2.0
# Liver Transplant           365.0   1.194521  1.075692  0.0   0.0   1.0   2.0
# Transplant                 365.0   0.561644  0.726014  0.0   0.0   0.0   1.0
# Pain                       365.0   0.526027  0.803500  0.0   0.0   0.0   1.0
# Interventional Radiology   365.0   0.216438  0.474346  0.0   0.0   0.0   0.0
# Anesthesia                 365.0   0.098630  0.349447  0.0   0.0   0.0   0.0
# Kidney Transplant          365.0   0.065753  0.248191  0.0   0.0   0.0   0.0
# Cardiovascular Transplant  365.0   0.049315  0.229143  0.0   0.0   0.0   0.0
# Gynecology                 365.0   0.046575  0.211017  0.0   0.0   0.0   0.0
#
#                             95%    97%   max
# HemeOnc/SCT                23.8  25.00  30.0
# Cardiology                 20.0  21.00  23.0
# General Pediatrics         21.0  22.00  25.0
# HemeOnc and StemCell       13.0  13.00  15.0
# Pulmonary                  11.8  13.00  16.0
# Green Team                 11.0  11.08  15.0
# General Surgery            10.0  11.00  14.0
# Red Team                    8.0   9.00  11.0
# Neurosurgery                8.0   8.00  10.0
# Orthopedics                 6.0   6.08   9.0
# Neurology                   4.0   5.00   7.0
# Urology                     3.0   3.00   4.0
# Plastic Surgery             2.8   3.00   5.0
# ENT                         4.0   5.00   8.0
# Unknown                     4.0   4.00   9.0
# Liver Transplant            3.0   4.00   5.0
# Transplant                  2.0   2.00   4.0
# Pain                        2.0   2.00   5.0
# Interventional Radiology    1.0   1.00   2.0
# Anesthesia                  1.0   1.00   3.0
# Kidney Transplant           1.0   1.00   1.0
# Cardiovascular Transplant   0.0   1.00   2.0
# Gynecology                  0.0   1.00   1.0

# %% [markdown]
# According to the slide, there is a growth factor for each service

# %%
service_count_daily = daily_census_adjust(service_count_daily)

# %%
# create a dictionary for optimazation
service_count_daily_dicts = [{service:row[service] for service in services_to_consider } 
                             for index, row in service_count_daily.iterrows()]

# %% [markdown]
# ## IP to solve the optimal allocation

# %%
from qpmodel import *
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# look at what we are solving
units_to_consider
services_to_consider
# Out:
# ['HemeOnc/SCT',
#  'Cardiology',
#  'General Pediatrics',
#  'HemeOnc and StemCell',
#  'Pulmonary',
#  'Green Team',
#  'General Surgery',
#  'Red Team',
#  'Neurosurgery',
#  'Orthopedics',
#  'Neurology',
#  'ENT',
#  'Liver Transplant',
#  'Intensive Care',
#  'Urology',
#  'Plastic Surgery',
#  'Transplant',
#  'Pain',
#  'Interventional Radiology',
#  'Anesthesia',
#  'Unknown',
#  'Cardiovascular Transplant',
#  'Kidney Transplant',
#  'Gynecology']

# %%
allocation = constrained_piecewise(services_to_consider, units_to_consider, service_count_daily_dicts,
                    unit_cap_dict, cap_thresh = 0.95)
# allocation = constrained_qp(services_to_consider, units_to_consider, service_count_daily_dicts,
#                     unit_cap_dict, cap_thresh = 0.90)
# Out:
# Optimize a model with 1922 rows, 2005 columns and 30543 nonzeros
# Model has 1885 piecewise-linear objective terms
# Variable types: 1885 continuous, 120 integer (120 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 3e+01]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 1885.0000000
# Presolve removed 91 rows and 127 columns
# Presolve time: 0.05s
# Presolved: 7288 rows, 9154 columns, 25603 nonzeros
# Presolved model has 1819 SOS constraint(s)
# Found heuristic solution: objective 1868.0000000
# Variable types: 5457 continuous, 3697 integer (3697 binary)
#
# Root relaxation: objective 9.585000e+02, 2971 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  958.50000    0  347 1868.00000  958.50000  48.7%     -    0s
# H    0     0                    1130.5000000  958.50000  15.2%     -    0s
#      0     0  958.50000    0  343 1130.50000  958.50000  15.2%     -    0s
# H    0     0                    1129.0000000  958.50000  15.1%     -    0s
#      0     0  958.50000    0  341 1129.00000  958.50000  15.1%     -    0s
#      0     0  958.50000    0  341 1129.00000  958.50000  15.1%     -    0s
# H    0     0                    1014.5000000  958.50000  5.52%     -    0s
#      0     2  958.50000    0  341 1014.50000  958.50000  5.52%     -    0s
# H  930    80                    1014.0000000  959.00000  5.42%  25.4    1s
# H  955    80                    1013.5000000  959.00000  5.38%  24.7    2s
# H 1744   176                    1011.0000000  959.00000  5.14%  35.0    3s
#   3485   238 infeasible  102      1011.00000  959.50000  5.09%  25.2    5s
# H 5000   286                    1010.9999998  960.00000  5.04%  21.0    6s
#
# Cutting planes:
#   MIR: 4
#
# Explored 5782 nodes (130601 simplex iterations) in 7.96 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 8: 1011 1011 1013.5 ... 1868
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.011000000096e+03, best bound 1.010999999846e+03, gap 0.0000%

# %%
# print the allocation
temp = allocation_to_dict(allocation, units_to_consider, services_to_consider)
for unit in temp:
    print(unit, temp[unit])
# Out:
# PCU200 ['Cardiology', 'ENT', 'Plastic Surgery', 'Cardiovascular Transplant']
# PCU300 ['Green Team', 'Red Team', 'Liver Transplant', 'Unknown', 'Transplant', 'Pain', 'Kidney Transplant']
# PCU360 ['General Surgery', 'Orthopedics', 'Interventional Radiology']
# PCU400 ['Pulmonary', 'Neurosurgery', 'Neurology', 'Urology', 'Anesthesia', 'Gynecology']
# PCU500 ['HemeOnc/SCT', 'General Pediatrics', 'HemeOnc and StemCell']

# %% [markdown]
# ## Calulate the performance

# %%
all_df
# Out:
#                            PCU200  PCU300  PCU360  PCU400  PCU500
# Service
# Cardiology                      1       0       0       0       0
# ENT                             1       0       0       0       0
# Plastic Surgery                 1       0       0       0       0
# Cardiovascular Transplant       1       0       0       0       0
# Green Team                      0       1       0       0       0
# Red Team                        0       1       0       0       0
# Liver Transplant                0       1       0       0       0
# Unknown                         0       1       0       0       0
# Transplant                      0       1       0       0       0
# Pain                            0       1       0       0       0
# Kidney Transplant               0       1       0       0       0
# General Surgery                 0       0       1       0       0
# Orthopedics                     0       0       1       0       0
# Interventional Radiology        0       0       1       0       0
# Pulmonary                       0       0       0       1       0
# Neurosurgery                    0       0       0       1       0
# Neurology                       0       0       0       1       0
# Urology                         0       0       0       1       0
# Anesthesia                      0       0       0       1       0
# Gynecology                      0       0       0       1       0
# HemeOnc/SCT                     0       0       0       0       1
# General Pediatrics              0       0       0       0       1
# HemeOnc and StemCell            0       0       0       0       1

# %%
from perform_utils import *

# %%
result = cal_daily_census(allocation, service_count_daily, units_to_consider, services_to_consider)

# %%
# plot the performance for each unit

f = plt.figure(figsize=(20,16))
off_unit_days = {}
for i in range(len(units_to_consider)):
    unit = units_to_consider[i]
    ax = f.add_subplot(3, 2, i+1)
    ax.plot(result[unit])
    ax.axhline(y=unit_cap_dict[unit], color='r', linestyle='-')
    ax.axhline(y=unit_cap_dict[unit]*0.9, color='g', linestyle='-')
    off_unit_days[unit] = cal_off_cap(result, unit, unit_cap_dict)
    ax.title.set_text(unit)
    ax.grid()
    
print('----off-service-stats----')
over_cap_count = 0
over_90_count = 0
for key in off_unit_days:
    aa, bb = off_unit_days[key]
    over_cap_count += aa
    over_90_count += bb
    print(key, off_unit_days[key])
print('----in-total----')
print(over_cap_count, over_90_count)
# Out:
# ----off-service-stats----
# PCU200 [3, 15]
# PCU300 [20, 46]
# PCU360 [7, 22]
# PCU400 [4, 11]
# PCU500 [31, 142]
# ----in-total----
# 65 236

# %% [markdown]
# ## Compare the current data with the slides

# %%
temp
# Out:
# {'PCU200': ['Cardiology',
#   'ENT',
#   'Plastic Surgery',
#   'Cardiovascular Transplant'],
#  'PCU300': ['Green Team',
#   'Red Team',
#   'Liver Transplant',
#   'Unknown',
#   'Transplant',
#   'Pain',
#   'Kidney Transplant'],
#  'PCU360': ['General Surgery', 'Orthopedics', 'Interventional Radiology'],
#  'PCU400': ['Pulmonary',
#   'Neurosurgery',
#   'Neurology',
#   'Urology',
#   'Anesthesia',
#   'Gynecology'],
#  'PCU500': ['HemeOnc/SCT', 'General Pediatrics', 'HemeOnc and StemCell']}

# %%
allocation_dict = {
'PCU200': ['Cardiology',
  'Cardiovascular Transplant'],
 'PCU300': ['Green Team',
  'Red Team',
  'Liver Transplant',
  'Transplant',
  'Kidney Transplant', 
  'Urology'],
 'PCU360': ['General Pediatrics', 'Plastic Surgery'],
 'PCU400': ['Pulmonary',
  'Neurosurgery',
  'Neurology',
  'ENT',
  'Orthopedics'],
 'PCU500': ['HemeOnc/SCT', 'General Surgery', 'HemeOnc and StemCell']
}
allocation = allocation_dict_to_dataframe(allocation_dict)
services_to_consider = [item for l in allocation_dict.values() for item in l]
result = cal_daily_census(allocation, service_count_daily, units_to_consider, services_to_consider)

# plot the performance for each unit

f = plt.figure(figsize=(20,16))
off_unit_days = {}
for i in range(len(units_to_consider)):
    unit = units_to_consider[i]
    ax = f.add_subplot(3, 2, i+1)
    ax.plot(result[unit])
    ax.axhline(y=unit_cap_dict[unit], color='r', linestyle='-')
    ax.axhline(y=unit_cap_dict[unit]*0.9, color='g', linestyle='-')
    off_unit_days[unit] = cal_off_cap(result, unit, unit_cap_dict)
    ax.title.set_text(unit)
    ax.grid()
    
print('----off-service-stats----')
print('[over_full_cap_days, over_90%_cap_days]')
over_cap_count = 0
over_90_count = 0
for key in off_unit_days:
    aa, bb = off_unit_days[key]
    over_cap_count += aa
    over_90_count += bb
    print(key, off_unit_days[key])
print('----in-total----')
print(over_cap_count, over_90_count)
# Out:
# ----off-service-stats----
# [over_full_cap_days, over_90%_cap_days]
# PCU200 [0, 1]
# PCU300 [30, 71]
# PCU360 [247, 299]
# PCU400 [13, 46]
# PCU500 [0, 0]
# ----in-total----
# 290 417

# %% [markdown]
# ## Original comparison

# %%
# calculate the original allocation
service_to_unit_orgin = {}
for service in services_to_consider:
    service_to_unit_orgin[service] = df_to_work.loc[df_to_work['Service.x'] == 
                                                    service]['Dept Abbrev'].value_counts().index[0]

allocation_orig = pd.DataFrame()
allocation_orig['Service'] = services_to_consider
for unit in units_to_consider:
    allocation_orig[unit] = 0
allocation_orig = allocation_orig.set_index('Service')

for service in services_to_consider:
    allocation_orig.loc[service, service_to_unit_orgin[service]] = 1

# %%
allocation_orig
# Out:
#                            PCU200  PCU300  PCU360  PCU400  PCU500
# Service
# HemeOnc/SCT                     0       0       0       0       1
# Cardiology                      1       0       0       0       0
# General Pediatrics              0       0       0       1       0
# HemeOnc and StemCell            0       0       0       0       1
# Pulmonary                       0       0       0       1       0
# Green Team                      0       1       0       0       0
# General Surgery                 0       1       0       0       0
# Red Team                        0       1       0       0       0
# Neurosurgery                    0       0       0       1       0
# Orthopedics                     0       0       0       1       0
# Neurology                       0       0       0       1       0
# Otolaryngology (ENT)            0       1       0       0       0
# Liver Transplant                0       1       0       0       0
# Intensive Care                  0       1       0       0       0
# Urology                         0       1       0       0       0
# Plastic Surgery                 0       1       0       0       0
# Transplant                      0       1       0       0       0
# Pain                            0       1       0       0       0
# Interventional Radiology        0       1       0       0       0
# Anesthesia                      0       0       0       1       0
# Unknown                         0       1       0       0       0
# Cardiovascular Transplant       1       0       0       0       0
# Kidney Transplant               0       1       0       0       0
# Gynecology                      0       1       0       0       0

# %%
# compare the original solution with the unconstrained allocation 

# f = plt.figure(figsize=(10,3))
# ax = f.add_subplot(121)
# ax2 = f.add_subplot(122)
# x = np.linspace(0,4,1000)
# ax.plot(x, np.sin(x))
# ax2.plot(x, np.cos(x), 'r:')

f = plt.figure(figsize=(20,16))
for i in range(len(units_to_consider)):
    unit = units_to_consider[i]
    ax = f.add_subplot(3, 2, i+1)
    ax.plot(results[0][unit], label = 'original')
    ax.plot(results[1][unit], label = 're-assigned')
    ax.axhline(y=unit_cap_dict[unit], color='r', linestyle='-')
    ax.axhline(y=unit_cap_dict[unit]*0.9, color='g', linestyle='-')
    print(unit, ':::')
    print(cal_off_cap(results[0], unit, unit_cap_dict))
    print(cal_off_cap(results[1], unit, unit_cap_dict))
    ax.legend()
    ax.title.set_text(unit)
    
# f = plt.figure(figsize=(10,3))
# # fig.subplots_adjust(hspace=1, wspace=2)
# for i in range(len(units_to_consider)):
#     unit = units_to_consider[i]
#     plt.subplot(3, 2, i+1)
#     plt.plot(results[0][unit])
# #     ax.text(0.5, 0.5, str((2, 3, i)),
# #            fontsize=18, ha='center')
# Out:
# PCU200 :::
# [0, 0]
# [7, 35]
# PCU300 :::
# [247, 302]
# [5, 28]
# PCU360 :::
# [0, 0]
# [6, 26]
# PCU400 :::
# [321, 352]
# [7, 44]
# PCU500 :::
# [0, 0]
# [9, 61]

# %%
services_to_consider
# Out:
# ['Hematology/Oncology',
#  'General Pediatrics',
#  'Stem Cell Transplant',
#  'Pulmonary',
#  'Gastroenterology',
#  'General Surgery',
#  'Nephrology',
#  'Neurosurgery',
#  'Orthopedic Surgery',
#  'Neurology',
#  'Liver Transplant',
#  'Otolaryngology (ENT)',
#  'Intensive Care',
#  'Urology',
#  'Rheumatology',
#  'Transplant Surgery',
#  'Plastic Surgery',
#  'Orthopedics',
#  'Oncology',
#  'Neonatology',
#  'Pain Management',
#  'Interventional Radiology',
#  'GI/Liver']

# %%
allocation_orig
# Out:
#                           HOPCU  SCTPCU  PCU300  PCU360  PCU400
# Service
# Hematology/Oncology           1       0       0       0       0
# General Pediatrics            0       0       0       0       1
# Stem Cell Transplant          0       1       0       0       0
# Pulmonary                     0       0       0       0       1
# Gastroenterology              0       0       1       0       0
# General Surgery               0       0       1       0       0
# Nephrology                    0       0       1       0       0
# Neurosurgery                  0       0       0       0       1
# Orthopedic Surgery            0       0       0       0       1
# Neurology                     0       0       0       0       1
# Liver Transplant              0       0       1       0       0
# Otolaryngology (ENT)          0       0       1       0       0
# Intensive Care                0       0       1       0       0
# Urology                       0       0       1       0       0
# Rheumatology                  0       0       1       0       0
# Transplant Surgery            0       0       1       0       0
# Plastic Surgery               0       0       1       0       0
# Orthopedics                   0       0       0       0       1
# Oncology                      1       0       0       0       0
# Neonatology                   0       0       1       0       0
# Pain Management               0       0       0       0       1
# Interventional Radiology      0       0       1       0       0
# GI/Liver                      0       0       1       0       0

# %%
a[('Hematology/Oncology', 'HOPCU')]
# Out:
# <gurobi.Var C690 (value 0.0)>

# %%
sol = pd.DataFrame()
